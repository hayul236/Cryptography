# %% [markdown]
# # FCS Lab 4 Submission Report
#
# - Nam Hayul
# - 1005611

# %%
import datetime
print("Execution time:", datetime.datetime.now(datetime.timezone.utc).strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# Execution time: 2025-06-30 11:44:44

# %% [markdown]
# ## PART I: Implementing PRESENT

# %%
# !python3 present.py
# Out:
# all key tests passed

# %% [markdown]
# ## Part II: Implementing ECB Mode

# %%
# !python ecb.py -i Tux.ppm -o Tux_encrypted.ppm -k key.txt -m encrypt

# %%
# !python ecb.py -i Tux_encrypted.ppm -o Tux_decrypted.ppm -k key.txt -m decrypt

# %% [markdown]
# ## Part II: Limitation of ECB Mode
