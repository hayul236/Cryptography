# %% [markdown]
# # FCS Lab 6 Submission Report
#
# - Nam Hayul
# - 1005611

# %%
import datetime
print("Execution time:", datetime.datetime.now(datetime.timezone.utc).strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# Execution time: 2025-07-27 12:15:01

# %% [markdown]
# ## Part I: Implementing Square and Multiply

# %%
# !python3 primes.py
# Out:
# Is 561 a prime?
# False
# Is 27 a prime?
# False
# Is 61 a prime?
# True
# Random number (100 bits):
# 1072559097203935014478841166047
# Random number (80 bits):
# 845099849611305623098333

# %% [markdown]
# ## Part II: Diffie-Hellman Key Exchange (DHKE)

# %%
# !python3 dhke.py
# Out:
# Generate P and alpha:
# P: 1208427317194081807087267
# alpha: 479558519074404771042571
#
# My private key is:  533174414337623041271785
# Test other private key is:  551950833871387690896423
#
# My public key is:  1041244542964153786203415
# Test other public key is:  639291249031874584187786
#
# My shared key is:  443203947910062765560577
# Test other shared key is:  443203947910062765560577
# Length of key is 79 bits.
