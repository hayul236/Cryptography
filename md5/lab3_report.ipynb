# %% [markdown]
# # FCS Lab 3 Submission Report
#
# - Nam Hayul
# - 1005611

# %%
import datetime
print("Execution time:", datetime.datetime.now(datetime.timezone.utc).strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# Execution time: 2025-06-22 11:52:56

# %% [markdown]
# ## Part I: Hashing Using MD5

# %%
import hashlib

random_strings=['hi', 'my name is', 'i love cybersec']

for string in random_strings:
    md5hash = hashlib.md5(string.encode()).hexdigest()
    print(f'Plaintext:{string} \nMD5 Hash: {md5hash} \nHash Length :{len(md5hash)} chars\n')
# Out:
# Plaintext:hi
# MD5 Hash: 49f68a5c8493ec2c0bf489821c21fc3b
# Hash Length :32 chars
#
# Plaintext:my name is
# MD5 Hash: 01365b2bab5c481ab2880c798c1110d8
# Hash Length :32 chars
#
# Plaintext:i love cybersec
# MD5 Hash: 56e255d987753741ccb8b0e620a9b17f
# Hash Length :32 chars

# %% [markdown]
# ## Part II: Break Hashes with Brute Froce

# %%
# !python3 ex2.py
# Out:
# All hashes matched.

# %% [markdown]
# ### how to run code: have an empty ex2_hash.txt and given hash5.txt, removes hash from hash5.txt, appends to ex2_hash.txt and continues running process until all has been found
# - time taken: ~ 3 minutes
# - average time to crack each string: ~ 12 seconds
# - is it possible to amortize?: probably not? need to test out all strings of requirement

# %% [markdown]
# ## Part III: Salt

# %%
# !python3 ex3.py
# Out:
# Salted hashes written to 'salted6.txt'
# Plain salted strings written to 'plain6.txt'
# Match found!
# String : aseas
# Salt   : w
# Hash   : cdcb659101cf9b8ed0fd9a9ea91d8719
# aseasw -> cdcb659101cf9b8ed0fd9a9ea91d8719
#
# Match found!
# String : cance
# Salt   : s
# Hash   : 5cb8c06dbbd994401768f3cadd2a7798
# cances -> 5cb8c06dbbd994401768f3cadd2a7798
#
# Match found!
# String : di5gv
# Salt   : n
# Hash   : 0e7e336141702c8480fd065483ae18d3
# di5gvn -> 0e7e336141702c8480fd065483ae18d3
#
# Match found!
# String : dsmto
# Salt   : v
# Hash   : cdc80eeb0002e1c5227e982003d93dde
# dsmtov -> cdc80eeb0002e1c5227e982003d93dde
#
# Match found!
# String : egunb
# Salt   : z
# Hash   : 53d0492a48fca47ada04c68d481b891f
# egunbz -> 53d0492a48fca47ada04c68d481b891f
#
# Match found!
# String : hed4e
# Salt   : m
# Hash   : e6a7f74830f74705ff1760abd08379e3
# hed4em -> e6a7f74830f74705ff1760abd08379e3
#
# Match found!
# String : lou0g
# Salt   : d
# Hash   : 2cfb92ae2db8c8bc4a409f7e75addbd2
# ...

# %% [markdown]
# - extra variable of salt value needed to account for matching
# - time taken is slightly longer
# - if salted value is unknown, much longer time will be needed to try all salt values: a,b,c,d...x,y,z
