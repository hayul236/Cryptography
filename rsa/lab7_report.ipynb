# %% [markdown]
# # FCS Lab 7 Submission Report
#
# - Nam Hayul
# - 1005611

# %%
import datetime
print("Execution time:", datetime.datetime.now(datetime.timezone.utc).strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# Execution time: 2025-08-10 11:09:53

# %% [markdown]
# ## Part II: RSA Without Padding

# %%
# !python ex2.py
# Out:
# Original message: Hello World! This is Sherlock.
#
# Encrypted message: 
#
# Decrypted message: Hello World! This is Sherlock.
#
# The decrypted message is the same as the original message.
#
# Message hash: 78fc1d99aa35b61ae1310555a252a9486d8f952aacc3319cb1d91e4035df7a3b
#
# Signature: 
#
# Verified signature: 78fc1d99aa35b61ae1310555a252a9486d8f952aacc3319cb1d91e4035df7a3b
#
# The received message signature is the same as the original message hash.

# %% [markdown]
# ## Part III: Protocol Attack

# %%
# !python ex3.py
# Out:
# Encrypting: 100
#
# Result:
# rxlR2g4GTbSwqCJD2umhMt5OYjVT3UZlborsn3rT81us+ewEhKq4Cmne0FTdsPat
# euER7lnWPARAWPyoPy//qxeo+c/2FRWSW6KCaP6UbSJi3K19tBpAr+u7G+VUYYCE
# 13txdfG4+Q/DANrxn3sgsPseLdsyASLkZxJuLruXERU=
#
# Modified to:
# BeTHxT0BG59cIWOYGGU/xWBa4Nws5aPMcDYLrpp5ye6g6/SAO/1jK3KirHi8bKJ3
# eQ9tvGU/fLi/y2AH7ZAAPSvOatrbpSVoeT8EFkNas/Hl8hnEgA6XVrY7ze/bhMLY
# 8nbysyxhwL1kWr3bopcBMjjRegIWQMxQ2Y3XkKSLnDY=
#
# Decrypted: 200

# %% [markdown]
# ## Part IV: RSA Digital Signature Protocol Attack|

# %%
# !python ex4.py
# Out:
# s: 
#
# x: 
#
# x': 
#
# accepted

# %% [markdown]
# ## Part V: Defending RSA with Padding

# %%
# !python ex5.py
# Out:
# Encrypted:
# NYSGkgmRHXVIOfrLAc345ugI44hSa7fBRzI0Dw+vn5FMW2NFqZwvvx8WvsITk2qkYumhvYSwguKFQfp4ZwGNEI7AmipyS/VMH8OZKJUt+HkEriHNlqnXc82j8RpQNfnwiWF5bJRe2MOGyLIz7MYmNSsW0sgb12sE6TKALkRWZtA=
#
# Decrypted:
# Hello, this is my data.
#
#
#
# Signature:
# DCZPrU6olRzLFDk+4EDgSOauijXt/q1/F9U2vlWIb1IeB9o6He9xNBB8+7Ak6+fGHFbnfLBLtWcBByGmZCI89p/sRHmNYWZRsyKga/qp5y+gX4gYIHiL3pP6w0D7GyFOv5AlC7++qHmOKWfus5ZxFSl9xoFyjIP1OrSR+oxhKX8=
#
# Signature valid? Yes
#
# Attack failed
